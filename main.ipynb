# %% [markdown]
# # [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JoseHernandez11/RL_JMHJDRJG/blob/main/main.ipynb)

# %% [markdown]
#  # Clonando el repositorio y configurando el entorno

# %%
# !git clone https://github.com/JoseHernandez11/RL_JMHJDRJG.git
# %cd RL_JMHJDRJG

# %% [markdown]
# # Breve descripción de los notebooks

# %%
# Listar notebooks disponibles
import os
notebooks = [f for f in os.listdir() if f.endswith('.ipynb')]
print("\n📂 Notebooks disponibles en el repositorio:")
for nb in notebooks:
    print(f"- {nb}")

# %% [markdown]
# Notebooks:
# * **P2_MonteCarlo.ipynb** : ejercicio 2a, construcción de un agente de Gimnasium que implemente el algoritmo de MonteCarlo.
# * **P2_EstudioAlgoritmos.ipynb** : ejercicio 2b, estudio comparativo entre distintos algoritmos estudiados.
#
# A continuación, se da la opción de navegar entre los notebooks.

# %%
# Generar enlaces de navegación para los notebooks en el repo
from IPython.display import display, Markdown
import os

repo_url = "https://colab.research.google.com/github/JoseHernandez11/k_brazos_JMHJDRJG/blob/main/"
notebooks = [f for f in os.listdir() if f.endswith('.ipynb')]

md_links = "## 📂 Navegar entre Notebooks\n"
for nb in notebooks:
    md_links += f"- [{nb}]({repo_url}{nb})\n"

display(Markdown(md_links))
